# %%
import scanpy as sc
# Out:
# /nfs/software/stegle/users/acuomo/conda-envs/myscanpy/lib/python3.7/site-packages/anndata/_core/anndata.py:21: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import RangeIndex

# %%
mydir = "/nfs/leia/research/stegle/dseaton/hipsci/singlecell_neuroseq/data/data_processed/"

# %%
#### Day 30
file0 = mydir+"pool1_13_noddd_D30/pool1_13_noddd_D30.scanpy.w_metadata.w_celltype.scanpy.h5"
d30 = sc.read(file0)
# Out:
# WARNING: Your filename has more than two extensions: ['.scanpy', '.w_metadata', '.w_celltype', '.scanpy', '.h5'].
# Only considering the two last: ['.scanpy', '.h5'].
# WARNING: Your filename has more than two extensions: ['.scanpy', '.w_metadata', '.w_celltype', '.scanpy', '.h5'].
# Only considering the two last: ['.scanpy', '.h5'].

# %%
d30.n_obs
# Out:
# 250923

# %%
d30.obs.head()
# Out:
#                      batch          donor_id        sample_id  cluster_id  \
# index
# AAACCTGAGAGCTATA-1-0     0  HPSI0714i-iudw_1  5245STDY7387187           0
# AAACCTGAGCTAGTCT-1-0     0  HPSI0114i-eipl_1  5245STDY7387187           3
# AAACCTGAGTGTTAGA-1-0     0  HPSI0614i-liqa_1  5245STDY7387187           2
# AAACCTGCAACCGCCA-1-0     0  HPSI0115i-paim_1  5245STDY7387187           1
# AAACCTGCAAGGGTCA-1-0     0  HPSI0114i-eipl_1  5245STDY7387187           1
#
#                      time_point pool_id treatment  n_counts_all celltype
# index
# AAACCTGAGAGCTATA-1-0        D30   pool1      NONE        4370.0       DA
# AAACCTGAGCTAGTCT-1-0        D30   pool1      NONE       19176.0    Epen1
# AAACCTGAGTGTTAGA-1-0        D30   pool1      NONE       11318.0     Sert
# AAACCTGCAACCGCCA-1-0        D30   pool1      NONE        5091.0    Astro
# AAACCTGCAAGGGTCA-1-0        D30   pool1      NONE        8612.0    Astro

# %%
### select DA only
d30_da = d30[d30.obs['celltype'] == 'DA']
d30_da.n_obs
# Out:
# 69007

# %%
d30_da.var
# Out:
#                    gene_ids-0       gene_ids-1       gene_ids-2  \
# index
# MIR1302-10    ENSG00000243485  ENSG00000243485  ENSG00000243485
# FAM138A       ENSG00000237613  ENSG00000237613  ENSG00000237613
# OR4F5         ENSG00000186092  ENSG00000186092  ENSG00000186092
# RP11-34P13.7  ENSG00000238009  ENSG00000238009  ENSG00000238009
# RP11-34P13.8  ENSG00000239945  ENSG00000239945  ENSG00000239945
# ...                       ...              ...              ...
# AC145205.1    ENSG00000215635  ENSG00000215635  ENSG00000215635
# BAGE5         ENSG00000268590  ENSG00000268590  ENSG00000268590
# CU459201.1    ENSG00000251180  ENSG00000251180  ENSG00000251180
# AC002321.2    ENSG00000215616  ENSG00000215616  ENSG00000215616
# AC002321.1    ENSG00000215611  ENSG00000215611  ENSG00000215611
#
#                    gene_ids-3       gene_ids-4       gene_ids-5  \
# index
# MIR1302-10    ENSG00000243485  ENSG00000243485  ENSG00000243485
# ...

# %%
#### Day 52
file1 = mydir+"pool1_17_D52/pool1_17_D52.scanpy.w_metadata.w_celltype.scanpy.h5"
d52 = sc.read(file1)
# Out:
# WARNING: Your filename has more than two extensions: ['.scanpy', '.w_metadata', '.w_celltype', '.scanpy', '.h5'].
# Only considering the two last: ['.scanpy', '.h5'].
# WARNING: Your filename has more than two extensions: ['.scanpy', '.w_metadata', '.w_celltype', '.scanpy', '.h5'].
# Only considering the two last: ['.scanpy', '.h5'].

# %%
d52.n_obs
# Out:
# 523094

# %%
d52.obs.head()
# Out:
#                      batch          donor_id  log1p_n_genes_by_counts  \
# index
# AAACCTGAGAAAGTGG-1-0     0  HPSI0114i-eipl_1                 7.883446
# AAACCTGAGATCTGCT-1-0     0  HPSI0114i-eipl_1                 8.137103
# AAACCTGAGCTAGTGG-1-0     0  HPSI0115i-paim_1                 7.958926
# AAACCTGAGGAGCGTT-1-0     0  HPSI0614i-liqa_1                 8.401782
# AAACCTGAGGTGCTTT-1-0     0  HPSI0114i-eipl_1                 8.187577
#
#                       log1p_total_counts  log1p_total_counts_mito  \
# index
# AAACCTGAGAAAGTGG-1-0            8.833463                 4.174387
# AAACCTGAGATCTGCT-1-0            9.267760                 5.549076
# AAACCTGAGCTAGTGG-1-0            8.898092                 4.997212
# AAACCTGAGGAGCGTT-1-0            9.901736                 6.864848
# AAACCTGAGGTGCTTT-1-0            9.341281                 5.068904
#
#                       n_genes_by_counts  pct_counts_in_top_100_genes  \
# index
# ...

# %%
### select DA only
d52_da = d52[d52.obs['celltype'] == 'DA']
d52_da.n_obs
# Out:
# 79801

# %%
d52_da.var = d30_da.var
d52_da.var
# Out:
#                    gene_ids-0       gene_ids-1       gene_ids-2  \
# index
# MIR1302-10    ENSG00000243485  ENSG00000243485  ENSG00000243485
# FAM138A       ENSG00000237613  ENSG00000237613  ENSG00000237613
# OR4F5         ENSG00000186092  ENSG00000186092  ENSG00000186092
# RP11-34P13.7  ENSG00000238009  ENSG00000238009  ENSG00000238009
# RP11-34P13.8  ENSG00000239945  ENSG00000239945  ENSG00000239945
# ...                       ...              ...              ...
# AC145205.1    ENSG00000215635  ENSG00000215635  ENSG00000215635
# BAGE5         ENSG00000268590  ENSG00000268590  ENSG00000268590
# CU459201.1    ENSG00000251180  ENSG00000251180  ENSG00000251180
# AC002321.2    ENSG00000215616  ENSG00000215616  ENSG00000215616
# AC002321.1    ENSG00000215611  ENSG00000215611  ENSG00000215611
#
#                    gene_ids-3       gene_ids-4       gene_ids-5  \
# index
# MIR1302-10    ENSG00000243485  ENSG00000243485  ENSG00000243485
# ...

# %%
d30_da
# Out:
# View of AnnData object with n_obs × n_vars = 69007 × 32738
#     obs: 'batch', 'donor_id', 'sample_id', 'cluster_id', 'time_point', 'pool_id', 'treatment', 'n_counts_all', 'celltype'
#     var: 'gene_ids-0', 'gene_ids-1', 'gene_ids-2', 'gene_ids-3', 'gene_ids-4', 'gene_ids-5', 'gene_ids-6', 'gene_ids-7', 'gene_ids-8', 'gene_ids-9', 'gene_ids-10', 'gene_ids-11', 'gene_ids-12', 'gene_ids-13', 'gene_ids-14', 'gene_ids-15', 'gene_ids-16', 'gene_ids-17', 'gene_ids-18', 'gene_ids-19', 'gene_ids-20', 'gene_ids-21', 'gene_ids-22', 'gene_ids-23', 'gene_ids-24', 'gene_ids-25', 'gene_ids-26', 'gene_ids-27', 'gene_ids-28', 'gene_ids-29', 'gene_ids-30', 'gene_ids-31', 'gene_ids-32', 'gene_ids-33'
#     obsm: 'X_umap'

# %%
d52_da
# Out:
# AnnData object with n_obs × n_vars = 79801 × 32738
#     obs: 'batch', 'donor_id', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'log1p_total_counts_mito', 'n_genes_by_counts', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'pct_counts_in_top_50_genes', 'pct_counts_mito', 'sample_id', 'total_counts', 'total_counts_mito', 'cluster_id', 'time_point', 'pool_id', 'treatment', 'n_counts_all', 'celltype'
#     var: 'gene_ids-0', 'gene_ids-1', 'gene_ids-2', 'gene_ids-3', 'gene_ids-4', 'gene_ids-5', 'gene_ids-6', 'gene_ids-7', 'gene_ids-8', 'gene_ids-9', 'gene_ids-10', 'gene_ids-11', 'gene_ids-12', 'gene_ids-13', 'gene_ids-14', 'gene_ids-15', 'gene_ids-16', 'gene_ids-17', 'gene_ids-18', 'gene_ids-19', 'gene_ids-20', 'gene_ids-21', 'gene_ids-22', 'gene_ids-23', 'gene_ids-24', 'gene_ids-25', 'gene_ids-26', 'gene_ids-27', 'gene_ids-28', 'gene_ids-29', 'gene_ids-30', 'gene_ids-31', 'gene_ids-32', 'gene_ids-33'
#     obsm: 'X_umap'

# %%
d30_da = d30_da.copy()

# %%
# d52_da = d52_da.copy()

# %%
all_da = d30_da.concatenate(d52_da, join="outer") # (148,808 cells x 32,738 genes)
all_da
# Out:
# AnnData object with n_obs × n_vars = 148808 × 32738
#     obs: 'batch', 'celltype', 'cluster_id', 'donor_id', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'log1p_total_counts_mito', 'n_counts_all', 'n_genes_by_counts', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'pct_counts_in_top_50_genes', 'pct_counts_mito', 'pool_id', 'sample_id', 'time_point', 'total_counts', 'total_counts_mito', 'treatment'
# ...

# %%
all_da.write("/hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_neuroseq/all_da_cells.h5")
# Out:
# ... storing 'donor_id' as categorical
# ... storing 'pool_id' as categorical
# ... storing 'sample_id' as categorical
# ... storing 'time_point' as categorical
# ... storing 'treatment' as categorical
