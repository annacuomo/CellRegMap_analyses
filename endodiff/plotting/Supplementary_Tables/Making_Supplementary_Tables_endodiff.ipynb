# %%
ST_dir = "/nfs/leia/research/stegle/acuomo/all_scripts/struct_LMM2/REVISION/Supplementary_Tables/"

# %%
list.files(ST_dir)
# Out:
# [1] "Supplementary_Table_3_betaGxC_endodiff.csv"
# [2] "Supplementary_Table_4_betaGxC_neuroseq.csv"

# %%
### single-cell GxC effect sizes (significant only, endodiff)

# %%
df_b = read.csv("/hps/nobackup2/stegle/users/acuomo/all_scripts/struct_LMM2/sc_endodiff/debug_May2021/genetic_effect/MOFA10/eqtl_tot_genetic_effect_all.txt", sep="\t",row.names = 1)
colnames(df_b) = gsub("_\\.","-",colnames(df_b))
head(df_b)
# Out:
#             ENSG00000005059_CCDC109B-4_110648632_T_A
# 21843_1#10  -0.02336156
# 21843_1#100 -0.04797379
# 21843_1#101 -0.01707154
# 21843_1#102 -0.06849843
# 21843_1#103 -0.02065975
# 21843_1#105  0.03203034
#             ENSG00000006016_CRLF1-19_18735221_G_T
# 21843_1#10   0.037167263
# 21843_1#100 -0.002567715
# 21843_1#101 -0.038323702
# 21843_1#102  0.029141143
# 21843_1#103  0.017882432
# 21843_1#105  0.029327187
#             ENSG00000006459_KDM7A-7_139913409_G_A
# 21843_1#10  -0.029627685
# 21843_1#100 -0.050303678
# 21843_1#101  0.001072175
# 21843_1#102  0.006591071
# 21843_1#103 -0.019780588
# 21843_1#105 -0.015424171
#             ENSG00000013297_CLDN11-3_170402765_T_C
# 21843_1#10  0.18296979
# 21843_1#100 0.14204539
# 21843_1#101 0.05068042
# 21843_1#102 0.27772236
# 21843_1#103 0.12713250
# 21843_1#105 0.13315777
#             ENSG00000021300_PLEKHB1-11_73339784_G_A
# 21843_1#10  -0.03793941
# 21843_1#100 -0.06425603
# 21843_1#101 -0.04211749
# 21843_1#102  0.05210891
# ...

# %%
filename = paste0(ST_dir, "Supplementary_Table_3_betaGxC_endodiff.csv")

# %%
write.csv(df_b,filename)
