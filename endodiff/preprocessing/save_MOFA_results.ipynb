# %%
### in python
# after installing mofax: pip install git+https://github.com/gtca/mofax

# %%
import mofax as mfx
import pandas as pd

# %%
m = mfx.mofa_model("/hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_endodiff/debug_May2021/mofa_logcounts_model.hdf5")
df = pd.DataFrame(m.get_factors())

# %%
# cells x MOFA factors
df.shape
# Out:
# (34256, 20)

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.597704  1.067436  0.056496  1.347661  0.640743  0.337826 -0.466419
# 1  0.233285  2.137884  0.646811  1.129460 -0.352773 -0.091806  0.924137
# 2 -0.054712  1.786031 -0.099625  0.364118  0.057125  0.215032  0.242728
# 3 -0.730924  1.132253  0.195645  0.588264  1.548193  0.251288 -0.399754
# 4 -0.257399  1.515610 -0.154816  0.199532  0.719182 -0.296087 -0.426952
#
#           7         8         9        10        11        12        13  \
# 0  0.015208  0.292243 -0.632737 -0.583318  0.473121  0.454845 -0.991047
# 1 -0.373492  1.789593 -0.659233  0.462286 -0.138813 -2.220937  1.554073
# 2  0.075943  0.879961  0.680635  0.372930  0.268620 -2.024130  1.150452
# 3 -0.210800  0.115147  0.060057 -0.584682 -0.421879 -0.127777  0.157820
# 4 -0.229939  0.091292 -0.430566 -0.473848 -1.243472 -0.852861 -0.064272
#
#          14        15        16        17        18        19
# 0  0.906530 -0.786617  0.445996 -1.810175 -1.039795  0.268045
# 1 -1.517363 -0.350251 -0.165591  1.199816  0.729859  0.048444
# 2 -0.054901 -0.459422  0.421497  1.172856  0.729108 -0.124239
# 3  0.735246 -1.818381 -0.148435 -0.168095 -0.770380  1.124324
# 4  0.321025 -0.666393  0.455624 -0.410516 -0.600952  0.304595

# %%
df.to_csv("/hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_endodiff/debug_May2021/mofa_logcounts_model_factors.csv")

# %%
df_weights = pd.DataFrame(data = m.get_weights(), index=m.features['scRNAseq'])

# %%
# highly variable genes x MOFA factors
df_weights.shape
# Out:
# (500, 20)

# %%
df_weights.head()
# Out:
#                                   0         1         2         3         4  \
# ENSG00000002330_BAD        0.309349 -0.403409 -0.334949 -0.231885  0.111686
# ENSG00000002586_CD99       0.955785 -0.551796 -0.061857 -0.296490  0.012552
# ENSG00000003402_CFLAR      1.609309 -0.714001 -0.110704 -0.104842 -0.201399
# ENSG00000006327_TNFRSF12A -0.091529 -0.418872 -0.530637  0.187189  0.680420
# ENSG00000007520_TSR3      -0.121021 -0.105043 -0.269050 -0.330089  0.224540
#
#                                   5         6         7         8         9  \
# ENSG00000002330_BAD       -0.121436 -0.009702 -0.007216  0.203540  0.042532
# ENSG00000002586_CD99       0.063665  0.054979  0.323430 -0.205452  0.231918
# ENSG00000003402_CFLAR      0.099246  0.060098  0.142381 -0.114982  0.211039
# ENSG00000006327_TNFRSF12A  0.040228  0.173707 -0.205643  0.262213 -0.042168
# ENSG00000007520_TSR3      -0.102408  0.162667  0.400854  0.151870 -0.590641
#
#                                  10        11        12        13        14  \
# ENSG00000002330_BAD        0.214578 -0.000915  0.020938 -0.158801 -0.087714
# ENSG00000002586_CD99       0.176637 -0.001796  0.149019 -0.061686 -0.075103
# ENSG00000003402_CFLAR     -0.087781 -0.079338  0.041760 -0.082411  0.035230
# ENSG00000006327_TNFRSF12A -0.269010 -0.023715  0.099654 -0.266476 -0.218568
# ENSG00000007520_TSR3      -0.129488 -0.043030 -0.061888  0.119843  0.123270
#
#                                  15        16        17        18        19
# ENSG00000002330_BAD        0.035739 -0.075752 -0.039573  0.029645  0.033884
# ENSG00000002586_CD99       0.036792 -0.077728 -0.119289 -0.002683 -0.089088
# ENSG00000003402_CFLAR      0.003756 -0.063092 -0.054066  0.024375 -0.001805
# ENSG00000006327_TNFRSF12A -0.039887  0.052164 -0.003976 -0.066725 -0.003094
# ENSG00000007520_TSR3       0.014822  0.131857 -0.009679  0.121841  0.095756

# %%
df_weights.to_csv("/hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_endodiff/debug_May2021/mofa_logcounts_model_weights.csv")
